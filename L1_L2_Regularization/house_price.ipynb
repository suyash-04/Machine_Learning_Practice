# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
dataset = pd.read_csv("melb_data.csv")
dataset.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
dataset.shape
# Out:
# (13580, 21)

# %%
data_to_use = ['Suburb', 'Rooms','Type','Method','SellerG','Regionname','Propertycount','Distance','CouncilArea',
               'Bedroom2','Bathroom','Car','Landsize','BuildingArea','Price']
dataset = dataset[data_to_use]
dataset.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
# 3  Abbotsford      3    h     PI  Biggin  Northern Metropolitan
# 4  Abbotsford      4    h     VB  Nelson  Northern Metropolitan
#
#    Propertycount  Distance CouncilArea  Bedroom2  Bathroom  Car  Landsize  \
# 0         4019.0       2.5       Yarra       2.0       1.0  1.0     202.0
# 1         4019.0       2.5       Yarra       2.0       1.0  0.0     156.0
# 2         4019.0       2.5       Yarra       3.0       2.0  0.0     134.0
# 3         4019.0       2.5       Yarra       3.0       2.0  1.0      94.0
# 4         4019.0       2.5       Yarra       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price
# 0           NaN  1480000.0
# 1          79.0  1035000.0
# 2         150.0  1465000.0
# ...

# %%
dataset.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          0
# Propertycount       0
# Distance            0
# CouncilArea      1369
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# Price               0
# dtype: int64

# %%
dataset['BuildingArea'] = dataset['BuildingArea'].fillna(dataset['BuildingArea'].mean())
dataset['Car'] = dataset['Car'].fillna(dataset['Car'].mean())
dataset['CouncilArea'] = dataset['CouncilArea'].fillna(0)
dataset.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
dataset = pd.get_dummies(dataset, drop_first= True).astype(int)
dataset.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2           4019         2         2         1    1       202
# 1      2           4019         2         2         1    0       156
# 2      3           4019         2         3         2    0       134
# 3      3           4019         2         3         2    1        94
# 4      4           4019         2         3         1    2       120
#
#    BuildingArea    Price  Suburb_Aberfeldie  ...  CouncilArea_Moreland  \
# 0           151  1480000                  0  ...                     0
# 1            79  1035000                  0  ...                     0
# 2           150  1465000                  0  ...                     0
# 3           151   850000                  0  ...                     0
# 4           142  1600000                  0  ...                     0
#
#    CouncilArea_Nillumbik  CouncilArea_Port Phillip  CouncilArea_Stonnington  \
# ...

# %%
X = dataset.drop('Price', axis = 'columns')
y = dataset.Price

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, y_train , y_test = train_test_split(X,y,test_size=0.3,random_state= 50)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# -2482360266628.747

# %%
model.score(X_train,y_train)
# Out:
# 0.7084744508962586

# %%
from sklearn import linear_model

lassso_reg = linear_model.Lasso(alpha= 20 , max_iter= 100 , tol = 0.1)

lassso_reg.fit(X_train,y_train)
# Out:
# c:\Users\Suyash\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.716e+14, tolerance: 3.799e+14
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=20, max_iter=100, tol=0.1)

# %%
lassso_reg.score(X_test,y_test)
# Out:
# 0.6535835646935264

# %%
lassso_reg.score(X_train,y_train)
# Out:
# 0.7069094509371452

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha= 20,max_iter=100,tol=0.1)
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=20, max_iter=100, tol=0.1)

# %%
ridge_reg.score(X_test,y_test)
# Out:
# 0.6644335105215096

# %%
ridge_reg.score(X_train,y_train)
# Out:
# 0.6838065337091896
